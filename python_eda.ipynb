# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
agg_trans = pd.read_csv("C:/Users/hp/Desktop/phone pe project dataset/agg_trans.csv")
agg_user = pd.read_csv("C:/Users/hp/Desktop/phone pe project dataset/agg_user.csv")
map_trans = pd.read_csv("C:/Users/hp/Desktop/phone pe project dataset/map_trans.csv")
map_user = pd.read_csv("C:/Users/hp/Desktop/phone pe project dataset/map_user.csv")
top_trans_dist = pd.read_csv("C:/Users/hp/Desktop/phone pe project dataset/top_trans_dist.csv")

# %%
agg_trans.head()
# Out:
#                          State  Year  Quarter          Transaction_type  \
# 0  Andaman and Nicobar Islands  2018        1  Recharge & bill payments
# 1  Andaman and Nicobar Islands  2018        1     Peer-to-peer payments
# 2  Andaman and Nicobar Islands  2018        1         Merchant payments
# 3  Andaman and Nicobar Islands  2018        1        Financial Services
# 4  Andaman and Nicobar Islands  2018        1                    Others
#
#    Transaction_count  Transaction_amount           Region
# 0               4200        1.845307e+06  Southern Region
# 1               1871        1.213866e+07  Southern Region
# 2                298        4.525072e+05  Southern Region
# 3                 33        1.060142e+04  Southern Region
# 4                256        1.846899e+05  Southern Region

# %%
agg_trans.shape
# Out:
# (3594, 7)

# %%
agg_trans.columns
# Out:
# Index(['State', 'Year', 'Quarter', 'Transaction_type', 'Transaction_count',
#        'Transaction_amount', 'Region'],
#       dtype='object')

# %%
agg_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3594 entries, 0 to 3593
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               3594 non-null   object
#  1   Year                3594 non-null   int64
#  2   Quarter             3594 non-null   int64
#  3   Transaction_type    3594 non-null   object
#  4   Transaction_count   3594 non-null   int64
#  5   Transaction_amount  3594 non-null   float64
#  6   Region              3594 non-null   object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 196.7+ KB

# %%
agg_trans.isnull().sum()
# Out:
# State                 0
# Year                  0
# Quarter               0
# Transaction_type      0
# Transaction_count     0
# Transaction_amount    0
# Region                0
# dtype: int64

# %%
agg_trans.duplicated().sum()
# Out:
# np.int64(0)

# %%
agg_trans['State'].unique()
# Out:
# array(['Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
agg_trans['Transaction_type'].unique()
# Out:
# array(['Recharge & bill payments', 'Peer-to-peer payments',
#        'Merchant payments', 'Financial Services', 'Others'], dtype=object)

# %%
agg_trans.describe()
# Out:
#               Year      Quarter  Transaction_count  Transaction_amount
# count  3594.000000  3594.000000       3.594000e+03        3.594000e+03
# mean   2020.001948     2.501113       1.995652e+07        3.378017e+10
# std       1.414507     1.118189       7.032910e+07        1.417195e+11
# min    2018.000000     1.000000       2.000000e+00        3.439721e+01
# 25%    2019.000000     2.000000       4.134475e+04        2.690695e+07
# 50%    2020.000000     3.000000       3.637465e+05        2.862499e+08
# 75%    2021.000000     4.000000       6.380843e+06        5.641061e+09
# max    2022.000000     4.000000       1.025666e+09        2.393380e+12

# %%
agg_user.head()
map_trans.head()
map_user.head()
top_trans_dist.head()
# Out:
#                          State  Year  Quarter                  District  \
# 0  Andaman and Nicobar Islands  2018        1             South Andaman
# 1  Andaman and Nicobar Islands  2018        1                  Nicobars
# 2  Andaman and Nicobar Islands  2018        1  North and Middle Andaman
# 3  Andaman and Nicobar Islands  2018        2             South Andaman
# 4  Andaman and Nicobar Islands  2018        2                  Nicobars
#
#    Transaction_count  Transaction_amount   Latitude  Longitude  \
# 0               5688        1.256025e+07  10.705690  92.487468
# 1                528        1.139849e+06  10.705690  92.487468
# 2                442        9.316631e+05  11.554828  92.238490
# 3               9395        2.394824e+07  10.705690  92.487468
# 4               1120        3.072437e+06  10.705690  92.487468
#
#             Region
# 0  Southern Region
# 1  Southern Region
# 2  Southern Region
# 3  Southern Region
# 4  Southern Region

# %%
agg_user.shape
map_trans.shape
map_user.shape
top_trans_dist.shape
# Out:
# (5920, 9)

# %%
agg_user.columns
map_trans.columns
map_user.columns
top_trans_dist.columns
# Out:
# Index(['State', 'Year', 'Quarter', 'District', 'Transaction_count',
#        'Transaction_amount', 'Latitude', 'Longitude', 'Region'],
#       dtype='object')

# %%
agg_user.info()
map_trans.info()
map_user.info()
top_trans_dist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6732 entries, 0 to 6731
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              6732 non-null   object
#  1   Year               6732 non-null   int64
#  2   Quarter            6732 non-null   int64
#  3   Brand              6732 non-null   object
#  4   Transaction_count  6732 non-null   int64
#  5   Percentage         6732 non-null   float64
#  6   Region             6732 non-null   object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 368.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14636 entries, 0 to 14635
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               14636 non-null  object
#  1   Year                14636 non-null  int64
#  2   Quarter             14636 non-null  int64
# ...

# %%
agg_user.isnull().sum()
map_trans.isnull().sum()
map_user.isnull().sum()
top_trans_dist.isnull().sum()
# Out:
# State                 0
# Year                  0
# Quarter               0
# District              0
# Transaction_count     0
# Transaction_amount    0
# Latitude              0
# Longitude             0
# Region                0
# dtype: int64

# %%
agg_user.drop_duplicates(inplace=True)
map_trans.drop_duplicates(inplace=True)
map_user.drop_duplicates(inplace=True)
top_trans_dist.drop_duplicates(inplace=True)

# %%
state_trans = agg_trans.groupby("State")["Transaction_amount"].sum().sort_values(ascending=False)

state_trans.head(10)
# Out:
# State
# Telangana         1.652292e+13
# Maharashtra       1.477133e+13
# Karnataka         1.387433e+13
# Andhra Pradesh    1.158475e+13
# Rajasthan         9.110360e+12
# Uttar Pradesh     8.179116e+12
# Madhya Pradesh    7.026999e+12
# Bihar             5.649345e+12
# Delhi             5.111844e+12
# West Bengal       4.969909e+12
# Name: Transaction_amount, dtype: float64

# %%
state_trans.head(10).plot(kind="bar", figsize=(10,5))

plt.title("Top 10 States by Transaction Amount")
plt.xlabel("State")
plt.ylabel("Transaction Amount")

plt.show()

# %%
type_analysis = agg_trans.groupby("Transaction_type")["Transaction_amount"].sum()

type_analysis
# Out:
# Transaction_type
# Financial Services          4.951071e+10
# Merchant payments           1.923232e+13
# Others                      1.145732e+11
# Peer-to-peer payments       9.726076e+13
# Recharge & bill payments    4.748767e+12
# Name: Transaction_amount, dtype: float64

# %%
type_analysis = agg_trans.groupby("Transaction_type")["Transaction_amount"].sum()

type_analysis
# Out:
# Transaction_type
# Financial Services          4.951071e+10
# Merchant payments           1.923232e+13
# Others                      1.145732e+11
# Peer-to-peer payments       9.726076e+13
# Recharge & bill payments    4.748767e+12
# Name: Transaction_amount, dtype: float64

# %%
type_analysis.plot(kind="pie", autopct="%1.1f%%")

plt.title("Transaction Type Distribution")
plt.show()

# %%
yearly_trans = agg_trans.groupby("Year")["Transaction_amount"].sum()

yearly_trans
# Out:
# Year
# 2018    1.623045e+12
# 2019    6.276688e+12
# 2020    1.464116e+13
# 2021    3.459870e+13
# 2022    6.426633e+13
# Name: Transaction_amount, dtype: float64

# %%
yearly_trans.plot(kind="line", marker="o")

plt.title("Yearly Transaction Growth")
plt.xlabel("Year")
plt.ylabel("Transaction Amount")

plt.show()

# %%
brand_usage = agg_user.groupby("Brand")["Transaction_count"].sum().sort_values(ascending=False)
brand_usage
# Out:
# Brand
# Xiaomi        869562617
# Samsung       671603711
# Vivo          625415019
# Oppo          420250245
# Others        282950234
# Realme        219973222
# Apple          95947314
# Motorola       73340734
# OnePlus        63677211
# Huawei         57129693
# Lenovo         42564548
# Tecno          12388623
# Micromax       11132859
# Infinix         5142870
# Asus            4295498
# Gionee          3082772
# Lava            1530109
# HMD Global       336632
# Lyf                1271
# COOLPAD              10
# Name: Transaction_count, dtype: int64

# %%
brand_usage.plot(kind="line", marker="o")

plt.title("User Growth Over Years")
plt.show()

# %%
yearly_trans = agg_trans.groupby("Year")["Transaction_amount"].sum()

yearly_trans
# Out:
# Year
# 2018    1.623045e+12
# 2019    6.276688e+12
# 2020    1.464116e+13
# 2021    3.459870e+13
# 2022    6.426633e+13
# Name: Transaction_amount, dtype: float64

# %%
yearly_trans.plot(kind="line", marker="o")

plt.title("Yearly Transaction Growth")
plt.xlabel("Year")
plt.ylabel("Transaction Amount")

plt.show()

# %%
district_trans = map_trans.groupby("District")["Transaction_amount"].sum().sort_values(ascending=False)

district_trans.head(10)
# Out:
# District
# Bengaluru Urban       7.823463e+12
# Hyderabad             7.736240e+12
# Pune                  4.515688e+12
# Jaipur                4.036183e+12
# Rangareddy            1.963870e+12
# Central Delhi         1.946607e+12
# Patna                 1.821164e+12
# Bhopal                1.747506e+12
# Medchal Malkajgiri    1.653635e+12
# Visakhapatnam         1.609891e+12
# Name: Transaction_amount, dtype: float64

# %%
district_trans.head(10).plot(kind="bar")

plt.title("Top Districts by Transactions")

plt.show()

# %%
top_trans_dist.sort_values(by="Transaction_amount", ascending=False).head(10)
# Out:
#           State  Year  Quarter         District  Transaction_count  \
# 5150  Telangana  2022        4        Hyderabad         1133829812
# 5140  Telangana  2022        3        Hyderabad         1018658174
# 2570  Karnataka  2022        4  Bengaluru Urban          876647100
# 2550  Karnataka  2022        2  Bengaluru Urban          786978117
# 2560  Karnataka  2022        3  Bengaluru Urban          738035161
# 2540  Karnataka  2022        1  Bengaluru Urban          648380838
# 5130  Telangana  2022        2        Hyderabad          446470234
# 2530  Karnataka  2021        4  Bengaluru Urban          584958847
# 5120  Telangana  2022        1        Hyderabad          372711414
# 4670  Rajasthan  2022        4           Jaipur          404922774
#
#       Transaction_amount   Latitude  Longitude           Region
# 5150        1.753799e+12  16.500000  78.250000  Southern Region
# 5140        1.586047e+12  16.500000  78.250000  Southern Region
# ...

# %%
brand_usage = agg_user.groupby("Brand")["Transaction_count"].sum().sort_values(ascending=False)

brand_usage
# Out:
# Brand
# Xiaomi        869562617
# Samsung       671603711
# Vivo          625415019
# Oppo          420250245
# Others        282950234
# Realme        219973222
# Apple          95947314
# Motorola       73340734
# OnePlus        63677211
# Huawei         57129693
# Lenovo         42564548
# Tecno          12388623
# Micromax       11132859
# Infinix         5142870
# Asus            4295498
# Gionee          3082772
# Lava            1530109
# HMD Global       336632
# Lyf                1271
# COOLPAD              10
# Name: Transaction_count, dtype: int64

# %%
brand_usage.head(10).plot(kind="bar", color="purple")
plt.title("Top 10 Mobile Brands Used for PhonePe")
plt.xlabel("Mobile Brand")
plt.ylabel("Transaction Count")
plt.xticks(rotation=45)
plt.show()

# %%
state_usage = agg_user.groupby("State")["Transaction_count"].sum().sort_values(ascending=False)

state_usage.head(10)
# Out:
# State
# Maharashtra       452075011
# Uttar Pradesh     355969633
# Karnataka         291372780
# Andhra Pradesh    225414835
# Rajasthan         215645588
# Telangana         211907753
# West Bengal       206129775
# Tamil Nadu        193665028
# Gujarat           180731308
# Madhya Pradesh    180662446
# Name: Transaction_count, dtype: int64

# %%
state_usage.head(10).plot(kind="bar", color="green")

plt.title("Top 10 States Using PhonePe")
plt.xlabel("State")
plt.ylabel("Transaction Count")
plt.show()

# %%
region_usage = agg_user.groupby("Region")["Transaction_count"].sum()

region_usage
# Out:
# Region
# Central Region           590768993
# Eastern Region           554389463
# North-Eastern Region      56370290
# Northern Region          395852891
# Southern Region         1010595129
# Western Region           852348426
# Name: Transaction_count, dtype: int64

# %%
region_usage.plot(kind="pie", autopct='%1.1f%%', figsize=(6,6))

plt.title("PhonePe Usage by Region")
plt.ylabel("")
plt.show()

# %%
yearly_usage = agg_user.groupby("Year")["Transaction_count"].sum()

yearly_usage
# Out:
# Year
# 2018     292797872
# 2019     602811578
# 2020     922009385
# 2021    1269755730
# 2022     372950627
# Name: Transaction_count, dtype: int64

# %%
yearly_usage.plot(kind="line", marker="o", color="blue")

plt.title("Yearly Growth of PhonePe Users")
plt.xlabel("Year")
plt.ylabel("Transaction Count")
plt.grid(True)
plt.show()

# %%
quarter_usage = agg_user.groupby(["Year","Quarter"])["Transaction_count"].sum()

quarter_usage
# Out:
# Year  Quarter
# 2018  1           46877653
#       2           63648009
#       3           80010589
#       4          102261621
# 2019  1          123432188
#       2          141807654
#       3          159293319
#       4          178278417
# 2020  1          197574459
#       2          218995596
#       3          241168896
#       4          264270434
# 2021  1          284984511
#       2          305257101
#       3          328353856
#       4          351160262
# 2022  1          372950627
# Name: Transaction_count, dtype: int64

# %%
quarter_usage.plot(kind="line", figsize=(8,5))

plt.title("Quarterly PhonePe Usage Trend")
plt.show()

# %%
brand_share = agg_user.groupby("Brand")["Percentage"].mean().sort_values(ascending=False)

brand_share.head(10)
# Out:
# Brand
# Xiaomi      0.261338
# Samsung     0.192086
# Vivo        0.165996
# Oppo        0.115967
# Others      0.091004
# Realme      0.058966
# Apple       0.033533
# Micromax    0.024496
# OnePlus     0.023609
# Motorola    0.021733
# Name: Percentage, dtype: float64

# %%
brand_share.head(10).plot(kind="bar", color="orange")

plt.title("Top Mobile Brands Market Share in PhonePe Usage")
plt.show()

# %%
pivot = agg_user.pivot_table(
    values="Transaction_count",
    index="Year",
    columns="Quarter",
    aggfunc="sum"
)

sns.heatmap(pivot, annot=True, cmap="YlGnBu")
plt.title("PhonePe Transactions Heatmap")
plt.show()

# %%
pip install sqlalchemy pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 364.6 kB/s eta 0:00:05
#    --------- ------------------------------ 0.5/2.1 MB 364.6 kB/s eta 0:00:05
#    --------- ------------------------------ 0.5/2.1 MB 364.6 kB/s eta 0:00:05
#    --------- ------------------------------ 0.5/2.1 MB 364.6 kB/s eta 0:00:05
#    --------- ------------------------------ 0.5/2.1 MB 364.6 kB/s eta 0:00:05
#    -------------- ------------------------- 0.8/2.1 MB 291.8 kB/s eta 0:00:05
#    -------------- ------------------------- 0.8/2.1 MB 291.8 kB/s eta 0:00:05
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# Create engine
engine = create_engine("mysql+pymysql://root:yourpassword@localhost/phonepe_analysis")

# Load CSVs
agg_trans = pd.read_csv("C:/Users/hp/Desktop/phone pe project dataset/agg_trans.csv")
agg_user = pd.read_csv("C:/Users/hp/Desktop/phone pe project dataset/agg_user.csv")
map_trans = pd.read_csv("C:/Users/hp/Desktop/phone pe project dataset/map_trans.csv")
map_user = pd.read_csv("C:/Users/hp/Desktop/phone pe project dataset/map_user.csv")
top_trans_dist = pd.read_csv("C:/Users/hp/Desktop/phone pe project dataset/top_trans_dist.csv")

# Step 3: Clean column names (lowercase and replace spaces with underscores)
for df in [agg_trans, agg_user, map_trans, map_user, top_trans_dist]:
    df.columns = df.columns.str.lower().str.replace(" ", "_")

# Step 4: Optional - Calculate avg_transaction_value for agg_trans
agg_trans["avg_transaction_value"] = agg_trans["transaction_amount"] / agg_trans["transaction_count"]

# Step 5: Create SQLAlchemy engine (root user with your password)
engine = create_engine("mysql+pymysql://root:Aadesh121101@localhost/phonepe_analysis")

# Step 6: Load data into SQL tables
agg_trans.to_sql("agg_trans", engine, if_exists="replace", index=False)
agg_user.to_sql("agg_user", engine, if_exists="replace", index=False)
map_trans.to_sql("map_trans", engine, if_exists="replace", index=False)
map_user.to_sql("map_user", engine, if_exists="replace", index=False)
top_trans_dist.to_sql("top_trans_dist", engine, if_exists="replace", index=False)

print("✅ All 5 datasets loaded into MySQL successfully!")
# Out:
# ✅ All 5 datasets loaded into MySQL successfully!
